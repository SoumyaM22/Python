# %%
#Style & color - To Style & color background
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = sns.load_dataset("exercise")
print(data)

sns.set_style(style= "darkgrid")
#style : {darkgrid, whitegrid, dark, white, ticks}
sns.barplot(data= data, x="time",y="pulse",hue="diet")
plt.show()
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = sns.load_dataset("exercise")
#print(data)

sns.set_style(style= "ticks")
#style : {darkgrid, whitegrid, dark, white, ticks}
sns.barplot(data= data, x="time",y="pulse",hue="diet")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.palplot(sns.color_palette())
#palatte plot- Plot the values in a color palette as a horizontal array.
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#sns.palplot(sns.color_palette("viridis"))
sns.palplot(sns.color_palette("GnBu"))
sns.palplot(sns.color_palette("GnBu",3)) # if we want only 3 colors
#GnBu (GreenBlue)
sns.palplot(sns.color_palette("bwr"))
#PuBu (PurpleBlue)
sns.palplot(sns.color_palette("PiYG",3))
sns.palplot(sns.color_palette("spring",2))
plt.show()
