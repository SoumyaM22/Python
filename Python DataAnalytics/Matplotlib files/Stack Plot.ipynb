# %%
#A stack plot is useful for showing the composition of different categories over time
#  or another continuous variable. (stack of plots)
#Eg: a)Showing Composition Over Time
#a1) Sales by Region: Visualizing how sales from different regions contribute to total sales over time.
#a2) Market Share: Displaying the market share of different companies over time.
#b) Visualizing Data Contribution
#b1)Energy Consumption: Showing the contribution of different energy sources to total energy consumption.

import matplotlib.pyplot as plt

days = [1,2,3,4,5,6,7]
NOP1 = [5,10,30,20,35,60,80] #no. of people in week1[Mon,Tue,Wed,Thurs,Fri,Sat,Sun] to restaurant
NOP2 = [10,20,30,25,40,90,120] #no. of people in week2
NOP3 = [8,30,50,60,70,90,100] #no. of people in week3

#plt.stackplot(days,NOP1,NOP2,NOP3)
#plt.stackplot(days,NOP1,NOP2,NOP3,baseline="sym")
plt.stackplot(days,NOP1,NOP2,NOP3,colors=["pink","hotpink","magenta"])
plt.show()

# %%
##Couldn't find excel source file to import
